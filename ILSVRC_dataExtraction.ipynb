# %% [markdown]
# ## **ILSVRC Data Extraction from 155GB zipped File**

# %% [markdown]
# This script contains the process to extract data from 150GB zipped file

# %%
import zipfile
import pandas as pd
import os
import random
import shutil
from pathlib import Path

# Set random seed for reproducibility
random.seed(42)

# Providing the source path of zipped file
zip_path = "D:/DeepLearning_CS-898BD/Task1_dataset/imagenet-object-localization-challenge.zip"

# This path is used for a spliting task 
# Because we are targeting files from the Data folder and within train folder
target_path = "ILSVRC/Data/CLS-LOC/train/"

# Provide the local directory path to store extracted image files
local_folder = 'my_dataset/train'  
os.makedirs(local_folder, exist_ok=True)  # Ensure base directory exist.

# Opening the ZIP file 
with zipfile.ZipFile(zip_path, 'r') as zip_ref:

    # first list all files in the ZIP archive 
    all_paths = zip_ref.namelist()

    # Extracting class and image file names (only .jpeg files)
    data = []  # creat a list to store path to image files

    # Looping over all the path
    for path in all_paths:
        # Check if it's inside the target path 
        if target_path not in path:
            continue  # Skip to the next iteration
        
        # Split the path to get class name and image file from train folder with Data folder
        # and taking files which has .jpeg format
        if path.lower().endswith('.jpeg') and target_path in path:
            # Now splitting the path based on the target path
            parts = path.split(target_path)
            if len(parts) >= 2:
                remainder = parts[1]  # Everything after the target_path this contains class/image_name 
                if '/' in remainder:  # further spliting to get class and image name seperatly
                    class_name = remainder.split('/')[0]
                    image_file = os.path.basename(path)   
                    # Store class name , image path and full path as a tupple in tupple list
                    data.append((class_name, image_file, path))  

# Create a DataFrame and store data in the dataframe
df = pd.DataFrame(data, columns=['Class', 'ImageFile', 'FullPath'])
print(f"Found {len(df)} images in {len(df['Class'].unique())} classes")

# Now, Randomly select 100 classes. 100 classes are selected randomly maintaing reproducability
unique_classes = df['Class'].unique()
selected_classes = pd.Series(unique_classes).sample(n=min(100, len(unique_classes)), random_state=42).tolist()

# For each selected class, select random sample up to 500 images
sampled_data = []
for class_name in selected_classes:
    class_images = df[df['Class'] == class_name]
    sampled_images = class_images.sample(n=min(500, len(class_images)), random_state=42)
    sampled_data.append(sampled_images)

# Combine results into a single DataFrame. By this time we must get all 100x500 images into sampled df
sampled_df = pd.concat(sampled_data)
print(f"Selected {len(sampled_df)} images from {len(selected_classes)} classes")

# Final process of etracting images to local directory
with zipfile.ZipFile(zip_path, 'r') as zip_ref:

    # Create a temporary extraction directory to avoide file path issue
    temp_dir = Path('temp_extraction')
    temp_dir.mkdir(exist_ok=True)
    
    # itterate over the rows in sampled_df
    for _, row in sampled_df.iterrows():
        full_path = row['FullPath']
        class_name = row['Class']
        image_file = row['ImageFile']

        # Create a subdirectory for the class
        target_dir = Path(local_folder) / class_name
        target_dir.mkdir(parents=True, exist_ok=True)
        
        try:
            # Extracting Process starts
            # Extract to temporary directory first
            zip_ref.extract(full_path, path=temp_dir)
            
            # Source file path in the temp directory
            source_file = temp_dir / full_path
            
            # Destination file path
            dest_file = target_dir / image_file
            
            # Copy the file to the final destination which is local folder 
            # named as my_dataset in the project
            shutil.copy2(source_file, dest_file)
            
            print(f"Extracted: {image_file} to {target_dir}")
            
            # Clean up the extracted file to save space
            os.remove(source_file)
            
        except KeyError:
            print(f"File not found in ZIP: {full_path}")
        except Exception as e:
            print(f"Error processing {full_path}: {e}")

# Clean up temporary directory when finished
try:
    shutil.rmtree(temp_dir)
except Exception as e:
    print(f"Warning: Could not remove temporary directory: {e}")

print("Extraction complete!")
# Out:
# Found 1281167 images in 1000 classes
# Selected 50000 images from 100 classes
# Extracted: n03133878_2015.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7055.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8572.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11508.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7347.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3060.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7856.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6966.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_204.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2425.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13546.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7993.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_931.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4854.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13915.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12771.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1594.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8527.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6247.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_45.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_739.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_150.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4987.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13237.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4791.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1775.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2467.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6409.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12726.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2209.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2966.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11093.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4539.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2118.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6987.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10433.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6034.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3198.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1727.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2821.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6942.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_614.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7248.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8327.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8667.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10933.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3672.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7322.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1120.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_395.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1222.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6366.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1465.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12559.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13424.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11999.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8155.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3266.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11006.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5697.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5125.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11029.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5448.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_348.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2690.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9459.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5173.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7469.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4889.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2871.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3932.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12544.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1190.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3868.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3276.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2561.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3938.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2571.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3483.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11786.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7484.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3332.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3760.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11410.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1625.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6608.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2438.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3872.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7524.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3780.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12542.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7241.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2135.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3092.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12879.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4421.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5202.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7398.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5357.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9858.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11714.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4348.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4596.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6496.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7195.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10890.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2849.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4977.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6795.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13803.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6201.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7437.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_582.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4873.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_213.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10978.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9859.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8940.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5693.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13710.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_300.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1343.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12381.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2668.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8533.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4138.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_861.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13427.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3366.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8217.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1887.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3416.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6729.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13227.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6670.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1718.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3854.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2533.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6683.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7254.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1351.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3001.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4259.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_126.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6439.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4626.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_350.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9222.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8182.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11619.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5635.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10558.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13918.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7773.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1917.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9491.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4153.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1750.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2892.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2809.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11511.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8652.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1315.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13894.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5462.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7743.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1684.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2058.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3219.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8384.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4595.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6024.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6673.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6659.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1019.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3081.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2539.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_627.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11095.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4899.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1745.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3987.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2790.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9531.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7997.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6460.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1536.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5316.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6177.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2062.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5116.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8850.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_282.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7426.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6403.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_189.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3229.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4188.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_354.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7583.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4504.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6812.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7428.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_235.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2750.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4255.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4871.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11436.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_510.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8208.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4823.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12233.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6370.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3828.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2661.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_25.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4924.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3722.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4345.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6222.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2025.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11344.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4915.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1234.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4783.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4464.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6568.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11140.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12382.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3540.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4830.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2264.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12351.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7927.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_737.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13602.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4938.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7130.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_18.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4851.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4427.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1602.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3998.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10884.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3133.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_967.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2202.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12285.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3749.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11399.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9950.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13037.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5040.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12942.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4774.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13938.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4990.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_823.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4267.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_994.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2872.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6804.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6470.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4234.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7353.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6287.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10671.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10522.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13913.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2777.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12297.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_704.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_275.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10059.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2921.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_396.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7626.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_595.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5616.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4579.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2839.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2311.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9811.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3273.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11698.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4581.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3212.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3913.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5475.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9615.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7370.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9908.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13657.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_58.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3417.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4242.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2446.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11163.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11167.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_717.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13437.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10220.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3199.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4287.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1819.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2884.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5029.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8176.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5124.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3511.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3217.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2737.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_83.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2863.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8725.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6550.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2830.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1590.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8266.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13873.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4876.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10056.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10087.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1944.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7522.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9887.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6653.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13475.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_237.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1049.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9368.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6053.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6285.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5264.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3721.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2891.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4904.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3668.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7879.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6048.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_14199.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1732.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10442.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2160.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_456.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10918.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11752.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11014.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3628.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13451.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12083.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3716.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6768.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9296.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11277.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3965.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4985.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5968.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3717.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6358.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9833.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3595.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4968.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2752.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4981.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_749.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6600.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1985.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6476.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5741.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4382.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4540.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2763.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3555.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11121.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7946.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1153.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6055.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2565.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_226.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6892.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1647.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3578.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2396.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3561.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4020.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3082.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4853.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13016.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4261.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7030.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1193.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2499.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13893.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4746.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4155.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3919.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_360.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7963.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_147.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4129.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5136.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_218.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5393.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8095.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6190.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13023.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_12321.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9448.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4740.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7358.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11401.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6908.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9362.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5062.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1052.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2808.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1269.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13960.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1889.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2225.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2139.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1681.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_687.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3995.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6184.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7684.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6493.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3959.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4536.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_400.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5407.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_457.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11162.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7957.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6913.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8010.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_851.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8656.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1838.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_14161.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6925.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6678.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1959.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3464.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13555.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2624.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13858.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5501.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3099.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6249.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_187.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8603.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3232.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5127.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9355.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_9981.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1400.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_6323.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3927.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11244.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11605.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3549.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10591.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_611.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_383.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2969.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2950.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_1441.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13332.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3789.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5680.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_847.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2461.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5934.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11373.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11450.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3510.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11417.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_305.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_910.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5309.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_5463.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4934.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2887.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3600.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3590.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4205.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2258.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_13190.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_3087.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_8055.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_10083.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_193.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_2733.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_7812.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_4297.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11743.JPEG to my_dataset\train\n03133878
# Extracted: n03133878_11639.JPEG to my_dataset\train\n03133878
# Extracted: n03983396_20629.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3228.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1527.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2754.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4138.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11342.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4690.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2562.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_6283.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11167.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_393.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9278.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2555.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2706.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4401.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12449.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_7744.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3047.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_22376.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11974.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_269.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5711.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5820.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5982.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4606.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10389.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3518.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_20539.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4250.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_21042.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9521.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12042.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_65.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2259.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_19052.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5447.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5332.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4880.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2656.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_6185.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_278.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10916.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_14652.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_751.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_816.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12459.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10806.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4383.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2502.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_20197.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4300.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8591.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5886.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_15493.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2657.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4863.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2760.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10229.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1075.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9695.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_28.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10487.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5548.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10380.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12052.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3306.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_20762.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1990.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_22287.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8770.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9528.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_20368.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10930.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12337.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_23011.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_6242.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12936.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2300.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_6170.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12749.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17034.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_21973.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2556.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12225.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_13300.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2535.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10312.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4633.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_694.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5277.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10951.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9264.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4371.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1860.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2436.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_6104.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2409.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4024.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4298.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_13698.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_14326.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4266.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3327.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4752.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_20462.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1969.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5452.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5657.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17666.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12763.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12654.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4780.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_20329.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_23471.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12563.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10701.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3372.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5377.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8147.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9901.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5791.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5386.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17006.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4982.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2064.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10471.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4285.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_18639.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_14605.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1102.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11442.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8573.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1910.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_14917.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9813.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_23143.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2243.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8051.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1147.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1688.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2128.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1202.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3945.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_7722.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_16942.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1866.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9176.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3639.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9674.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10290.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_13764.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3248.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10309.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_16212.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5672.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_24781.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8633.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10874.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9420.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2507.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9543.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_13882.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3702.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_13193.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4313.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5139.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_22816.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10469.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11322.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11716.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2538.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1881.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2847.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2496.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4242.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_984.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2834.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_18604.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11236.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12745.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5592.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5726.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3015.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9050.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8372.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4295.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17074.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4760.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1762.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4882.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2109.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2134.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11887.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_7784.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2810.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_122.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4439.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_19068.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4587.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11907.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_18099.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9794.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1721.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_23972.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10581.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5384.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_24539.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12802.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10654.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5062.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11806.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11267.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1311.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2781.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_16828.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3136.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4292.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_7763.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_13434.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2102.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2579.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3709.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9199.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3182.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2198.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3170.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4735.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_18508.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5144.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2283.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3158.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_23944.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3749.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4791.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5161.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_19980.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4363.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_9150.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4477.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11894.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4212.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12860.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2856.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_486.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_24861.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12211.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2863.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4032.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1157.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4469.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1745.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_24815.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8684.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17343.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4829.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1496.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_12065.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_14552.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_14076.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_4165.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_10087.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11631.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_165.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_5363.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3989.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_16710.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3969.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_209.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_22357.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_1682.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_22326.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11513.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_15062.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17262.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2271.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3308.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_3661.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_11729.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_17636.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_6817.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_8101.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_2907.JPEG to my_dataset\train\n03983396
# Extracted: n03983396_589.JPEG to my_dataset\train\n03983396
# ...
# Extracted: n04328186_11920.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_48009.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10934.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2314.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14889.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12334.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26174.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10444.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1141.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_16897.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10761.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5458.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4797.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3520.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18225.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2608.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6837.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_44210.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4743.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18447.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4250.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_24260.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3549.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7211.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_8504.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4884.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11069.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_92.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11697.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_37455.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17324.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_54341.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17436.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_46118.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_20654.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14300.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26781.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_25496.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12068.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_52176.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27383.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_25010.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7156.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18408.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7952.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_16627.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6039.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2582.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_40397.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6460.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12859.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27587.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18681.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_53130.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27747.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4830.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3407.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10566.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14000.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15809.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_20764.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18897.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5016.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_41744.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21403.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19848.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7934.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7273.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11250.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_214.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6919.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5817.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_16401.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7139.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17900.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19404.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1508.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15415.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2704.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27613.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17792.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6803.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3122.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_8648.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15953.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_29912.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_255.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11365.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11734.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10600.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5444.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1654.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14741.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4213.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3519.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21965.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1149.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11585.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19846.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11579.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_8371.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_23979.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_8331.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27982.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7174.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_25088.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19467.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10067.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17861.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_25703.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11859.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11770.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19298.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3410.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17920.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_37591.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_668.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7905.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17214.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2848.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1675.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26486.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15468.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22033.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_13219.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7998.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2831.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12292.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_23996.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9586.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15998.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4923.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17240.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_30310.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10135.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21656.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1452.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_38090.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19391.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11570.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_24599.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27129.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_39292.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15544.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26891.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14839.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_54969.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_23454.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6210.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15176.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7616.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3112.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22537.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6102.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14158.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9170.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_252.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_23857.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4062.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21359.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22192.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_24036.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10104.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5126.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_13640.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19157.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4779.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1511.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1815.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5503.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_25448.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_574.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2155.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3469.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3929.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22206.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_23212.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_35491.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9151.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_34712.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_2631.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_29256.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_8713.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7764.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4862.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_981.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_13929.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_15179.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_23246.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7579.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14887.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_54794.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11526.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_13310.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17696.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22349.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21830.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27731.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22686.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10756.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_6812.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12728.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_32072.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9941.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_301.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17897.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_20601.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3748.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3845.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26827.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5976.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5334.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10004.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21130.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_19225.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1960.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1793.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_5630.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_48565.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3173.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22927.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_29476.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9145.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_43477.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14076.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_22105.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12421.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_25357.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26495.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_3246.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_8641.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11647.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9191.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1428.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_193.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26438.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17055.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_4806.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_16030.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_11298.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17447.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12627.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_17672.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_26835.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18135.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_1318.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_27669.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_36.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_423.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_12782.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_18535.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_7625.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_13975.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_10552.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_56.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_14488.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_9889.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_42087.JPEG to my_dataset\train\n04328186
# Extracted: n04328186_21584.JPEG to my_dataset\train\n04328186
# Extraction complete!
